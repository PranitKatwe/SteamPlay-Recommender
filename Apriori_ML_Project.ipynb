# %%
apriori = read.csv("apriori_platform.csv")
apriori
# Out:
#       X0      X1      X2
# 1     Mac     Linux   Windows
# 2     Mac     Linux   Windows
# 3     Mac     Linux   Windows
# 4     Mac     Linux   Windows
# 5     Mac     Linux   Windows
# 6     Mac     Linux   Windows
# 7     Mac     Linux   Windows
# 8     Mac     Linux   Windows
# 9     Mac     Linux   Windows
# 10    Mac     Linux   Windows
# 11    Mac     Linux   Windows
# 12    Mac     Linux   Windows
# 13    Mac     Linux   Windows
# 14    Mac     Linux   Windows
# 15    Mac     Linux   Windows
# 16    Mac     Linux   Windows
# 17    Mac     Linux   Windows
# 18    Mac     Linux   Windows
# 19    Mac     Linux   Windows
# 20    Mac     Linux   Windows
# 21    Mac     Linux   Windows
# 22    Mac     Windows
# 23    Mac     Linux   Windows
# 24    Mac     Linux   Windows
# 25    Mac     Linux   Windows
# 26    Windows
# 27    Mac     Linux   Windows
# 28    Mac     Linux   Windows
# 29    Windows
# 30    Mac     Linux   Windows
# ...   ...     ...     ...
# 13328 Windows
# ...

# %%
install.packages("arules")
# Out:
# Warning message:
# "package 'arules' is not available (for R version 3.6.1)"
